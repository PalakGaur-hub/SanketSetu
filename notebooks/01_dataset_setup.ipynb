# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# c:\Users\palak\SANKETSETU\notebooks

# %%
import os

# Look inside dataset/raw
RAW_PATH = os.path.join("..", "dataset", "raw")

print("RAW PATH:", os.path.abspath(RAW_PATH))
print("Exists:", os.path.exists(RAW_PATH))

print("\nContents of raw folder:")
for item in os.listdir(RAW_PATH):
    print("-", item)
# Out:
# RAW PATH: c:\Users\palak\SANKETSETU\dataset\raw
# Exists: True
#
# Contents of raw folder:
# - include.zip

# %%
import os

RAW_PATH = os.path.join("..", "dataset", "raw")

print(os.listdir(RAW_PATH))
# Out:
# ['include', 'include.zip']

# %%
import os

INCLUDE_PATH = os.path.join("..", "dataset", "raw", "include")

sign_folders = []

for part in os.listdir(INCLUDE_PATH):
    part_path = os.path.join(INCLUDE_PATH, part)

    if os.path.isdir(part_path):
        # Go inside the category folder (Colours, Animals, etc.)
        for category in os.listdir(part_path):
            category_path = os.path.join(part_path, category)

            if os.path.isdir(category_path):
                # Actual sign folders
                for sign in os.listdir(category_path):
                    sign_path = os.path.join(category_path, sign)

                    if os.path.isdir(sign_path):
                        sign_folders.append(sign)

print("Total sign folders:", len(sign_folders))

print("\nFirst 20 signs:")
for sign in sorted(sign_folders)[:20]:
    print(sign)
# Out:
# Total sign folders: 262
#
# First 20 signs:
# 1. Dog
# 1. Religion
# 1. loud
# 10. Energy
# 10. Mean
# 10. Plane
# 11. Car
# 11. War
# 11. rich
# 12. Peace
# 12. Truck
# 12. poor
# 13. Attack
# 13. Bicycle
# 13. thick
# 14. Bus
# 14. Election
# 14. thin
# 15. Boat
# 15. Newspaper
